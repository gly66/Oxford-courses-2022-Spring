# %%
import numpy as np
import pandas as pd
import random

a = np.random.randn(8,7)
df = pd.DataFrame(a)  #dataframe is a datatype of pandas
df[df>0.9] = np.nan
df
# Out:
#           0         1         2         3         4         5         6
# 0       NaN -0.829690 -1.008906 -0.335814 -0.218064  0.081450  0.000134
# 1 -0.036442  0.223414 -0.442250  0.192969       NaN  0.571043 -0.304061
# 2 -1.403317       NaN -1.242784       NaN       NaN  0.401176       NaN
# 3       NaN -0.227143       NaN -0.872553 -0.971812 -0.166083 -0.352945
# 4 -0.207970  0.135995 -0.577042       NaN       NaN  0.333179       NaN
# 5  0.500902 -2.173098 -0.220997  0.865067  0.316560  0.192627 -0.061252
# 6       NaN       NaN -0.722067 -0.502493 -0.214100 -0.823783  0.243251
# 7 -1.236790       NaN  0.669412 -0.152806  0.772910 -1.276735  0.250705

# %%
print(df.isnull())
# Out:
#        0      1      2      3      4      5      6
# 0   True  False  False  False  False  False  False
# 1  False  False  False  False   True  False  False
# 2  False   True  False   True   True  False   True
# 3   True  False   True  False  False  False  False
# 4  False  False  False   True   True  False   True
# 5  False  False  False  False  False  False  False
# 6   True   True  False  False  False  False  False
# 7  False   True  False  False  False  False  False

# %%
print(df.isnull().sum().sum())
# Out:
# 14

# %%
df.index = ['a', 'b' , 'c', 'd', 'e','f', 'g', 'h']
df
# Out:
#           0         1         2         3         4         5         6
# a       NaN -0.829690 -1.008906 -0.335814 -0.218064  0.081450  0.000134
# b -0.036442  0.223414 -0.442250  0.192969       NaN  0.571043 -0.304061
# c -1.403317       NaN -1.242784       NaN       NaN  0.401176       NaN
# d       NaN -0.227143       NaN -0.872553 -0.971812 -0.166083 -0.352945
# e -0.207970  0.135995 -0.577042       NaN       NaN  0.333179       NaN
# f  0.500902 -2.173098 -0.220997  0.865067  0.316560  0.192627 -0.061252
# g       NaN       NaN -0.722067 -0.502493 -0.214100 -0.823783  0.243251
# h -1.236790       NaN  0.669412 -0.152806  0.772910 -1.276735  0.250705

# %%
df.dropna() #strategey 1. just delete all the rows contain nan
# Out:
#           0         1         2         3        4         5         6
# f  0.500902 -2.173098 -0.220997  0.865067  0.31656  0.192627 -0.061252

# %%
df.fillna(0, inplace = True)  #strategy2. replace nan with 0
df
# Out:
#           0         1         2         3         4         5         6
# a  0.000000 -0.829690 -1.008906 -0.335814 -0.218064  0.081450  0.000134
# b -0.036442  0.223414 -0.442250  0.192969  0.000000  0.571043 -0.304061
# c -1.403317  0.000000 -1.242784  0.000000  0.000000  0.401176  0.000000
# d  0.000000 -0.227143  0.000000 -0.872553 -0.971812 -0.166083 -0.352945
# e -0.207970  0.135995 -0.577042  0.000000  0.000000  0.333179  0.000000
# f  0.500902 -2.173098 -0.220997  0.865067  0.316560  0.192627 -0.061252
# g  0.000000  0.000000 -0.722067 -0.502493 -0.214100 -0.823783  0.243251
# h -1.236790  0.000000  0.669412 -0.152806  0.772910 -1.276735  0.250705

# %%
a = np.random.randn(8,7)
df = pd.DataFrame(a)  #dataframe is a datatype of pandas
df[df>0.9] = np.nan
df
# Out:
#           0         1         2         3         4         5         6
# 0       NaN -1.235396 -0.978413  0.752793 -0.550329       NaN -0.612298
# 1  0.632288 -2.165868  0.135434  0.155184 -1.055520  0.713976  0.531045
# 2 -0.285638  0.076066 -0.451905  0.538492 -0.662153 -1.062815 -0.147047
# 3       NaN -0.572215  0.248171 -1.146014       NaN  0.495055  0.508174
# 4 -1.263051  0.767446       NaN -0.368219  0.397803  0.050927 -0.451495
# 5 -0.011902       NaN -0.517120       NaN -0.063177 -0.329035 -0.617454
# 6 -0.039126  0.275065 -0.863812 -0.122558  0.679090 -0.132699 -1.154298
# 7  0.868179 -0.372490 -0.177138  0.487776  0.312280       NaN -0.428237

# %%
for column_name in df:     # 3. replace nan with mean number 
    df[column_name].fillna(df[column_name].mean(), inplace = True)
df
# Out:
#           0         1         2         3         4         5         6
# 0 -0.016542 -1.235396 -0.978413  0.752793 -0.550329 -0.044098 -0.612298
# 1  0.632288 -2.165868  0.135434  0.155184 -1.055520  0.713976  0.531045
# 2 -0.285638  0.076066 -0.451905  0.538492 -0.662153 -1.062815 -0.147047
# 3 -0.016542 -0.572215  0.248171 -1.146014 -0.134572  0.495055  0.508174
# 4 -1.263051  0.767446 -0.372112 -0.368219  0.397803  0.050927 -0.451495
# 5 -0.011902 -0.461056 -0.517120  0.042493 -0.063177 -0.329035 -0.617454
# 6 -0.039126  0.275065 -0.863812 -0.122558  0.679090 -0.132699 -1.154298
# 7  0.868179 -0.372490 -0.177138  0.487776  0.312280 -0.044098 -0.428237

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8)

# %%
df = pd.read_csv('/Users/admin/Downloads/Sberbank Housing Market.csv')
df.shape
# Out:
# (30471, 292)

# %%
df.dtypes
# Out:
# id                      int64
# timestamp              object
# full_sq                 int64
# life_sq               float64
# floor                 float64
#                        ...
# mosque_count_5000       int64
# leisure_count_5000      int64
# sport_count_5000        int64
# market_count_5000       int64
# price_doc               int64
# Length: 292, dtype: object

# %%
from pandas.plotting import scatter_matrix
df_fewer_columns =df.iloc[:, 15:20:1]
scatter_matrix(df_fewer_columns, figsize = (12, 12));

# %%
import missingno as msno
df_some_columns = df.iloc[:, 0:30:1]
msno.matrix(df_some_columns)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df_some_columns)
# Out:
# <AxesSubplot:>

# %%
limitPer = len(df_some_columns) * .60
df_some_columns.dropna(axis='columns', thresh = limitPer, inplace = True)
msno.bar(df_some_colssumns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/k7/4bjv6l3x6595s25jdbrvtln40000gn/T/ipykernel_1337/3622911863.py in <module>
#       1 limitPer = len(df_some_columns) * .60
#       2 df_some_columns.dropna(axis='columns', thresh = limitPer, inplace = True)
# ----> 3 msno.bar(df_some_colssumns)
#
# NameError: name 'df_some_colssumns' is not defined

# %%
msno.heatmap(df)
